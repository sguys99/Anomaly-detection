# %% [markdown]
# # Credit Card Fraud Detection
# ### Recognize fraudulent credit card transactions
#              KwangMyung Yu, Senior Researcher, Korea Electric Power Corporation

# %% [markdown]
# ### 1. 데이터셋 확인

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import datetime
import missingno as msno
import warnings; warnings.filterwarnings('ignore')
plt.style.use('ggplot')
# %matplotlib inline

# Options for pandas
pd.options.display.max_columns = 30 #중요

# %%
color_pal = [ '#ee4035', '#3385c6', '#fed766','#eb6841', '#708090', 
	'#00a0b0', '#3b7dd8', '#fe4a49' , '#2ab7ca', '#851e3e', 
	'#2a4d69',  '#f7f7f7', '#edc951', '#54b2a9', '#ffffff', 
	'#96ceb4', '#ffeead', '#708090', '#be9b7b', '#feb2a8',
	'#58668b',  '#4f372d', '#ECD59F', '#ABD1DC', '#7E9680', 
    	'#E69D45', '#D4CFC9', '#E79796', '#C6C09C', '#dec3c3',
    	'#4b86b4', '#f9caa7', '#d2d4dc', '#ebf4f6', '#29a8ab' ]

# %%
data = pd.read_csv('data/creditcard.csv')

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  ...  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169  ...
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772  ...
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946  ...
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924  ...
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# ### 2. EDA

# %% [markdown]
# #### 2.1 결측치 확인

# %%
msno.bar(data, fontsize = 18)
plt.show()

# %%
data.isnull().sum().any()
# Out:
# False

# %% [markdown]
# #### 2.2 Target

# %%
fig, ax = plt.subplots(figsize = (12, 6))
data['Class'].value_counts().plot(kind = 'bar', color = color_pal[17:], 
                        edgecolor='#404040', ax = ax, fontsize = 12, rot = 0)

for p in ax.patches:
    ax.text(p.get_x()+p.get_width()/2., p.get_height()+3000, 
            str(p.get_height())+'('+str(round((p.get_height()/data.shape[0])*100,
            2))+ '%)', ha='center', fontsize = 20)

ax.set_xticklabels(['normal(0)', 'fraud(1)'], fontsize = 20)
plt.show()

# %% [markdown]
# #### 2.3 Features

# %% [markdown]
# **Time**

# %% [markdown]
# **Amount**
# - log scaling 필요

# %% [markdown]
# **V1 ~ 28**

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 6), gridspec_kw={'width_ratios': [2, 1]})
corr = data.corr()

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, vmax = 0.8, square = True, cmap =cmap, ax = axes[0])

corr = data.corrwith(data['Class']).reset_index()
corr.columns = ['Index','Correlations']
corr = corr.set_index('Index')
corr = corr.sort_values(by=['Correlations'], ascending = False)
sns.heatmap(corr, annot=True, fmt="g", cmap=cmap, ax = axes[1])
axes[1].set_title("Correlation of Variables with Class", fontsize = 12)
plt.subplots_adjust(wspace = 0.2)
plt.show()

# %% [markdown]
# - 확인 잘 안됨. 5:5 샘플링하여 실시 필요

# %% [markdown]
# ### 3. Feature Engineering

# %% [markdown]
# #### 3.1 Log scaling

# %%
data['Amount'] = np.log1p(data['Amount'])

# %%
fig, axes = plt.subplots(1, 2, figsize = (14, 4))
data['Amount'].plot(kind = 'hist', bins = 100, ax = axes[0], 
                    alpha = 0.7, density = True)
data['Amount'].plot(kind = 'kde', style = 'k--', ax = axes[0])
axes[0].set_title('Distribution of Transaction Amount(scaled)')
sp.stats.probplot(data['Amount'], plot= axes[1])
plt.show()

# %% [markdown]
# #### 3.2 MinMax Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data.iloc[:, 1:30]
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# ...

# %%
minmax = MinMaxScaler()
data.iloc[:, 1:30] = minmax.fit_transform(data.iloc[:, 1:30])

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0  0.935192  0.766490  0.881365  0.313023  0.763439  0.267669  0.266815
# 1   0.0  0.978542  0.770067  0.840298  0.271796  0.766120  0.262192  0.264875
# 2   1.0  0.935217  0.753118  0.868141  0.268766  0.762329  0.281122  0.270177
# 3   1.0  0.941878  0.765304  0.868484  0.213661  0.765647  0.275559  0.266803
# 4   2.0  0.938617  0.776520  0.864251  0.269796  0.762975  0.263984  0.268968
#
#          V8        V9       V10       V11       V12       V13       V14  ...  \
# 0  0.786444  0.475312  0.510600  0.252484  0.680908  0.371591  0.635591  ...
# 1  0.786298  0.453981  0.505267  0.381188  0.744342  0.486190  0.641219  ...
# 2  0.788042  0.410603  0.513018  0.322422  0.706683  0.503854  0.640473  ...
# 3  0.789434  0.414999  0.507585  0.271817  0.710910  0.487635  0.636372  ...
# 4  0.782484  0.490950  0.524303  0.236355  0.724477  0.552509  0.608406  ...
#
# ...

# %%
data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284807.000000  284807.000000  284807.000000  284807.000000
# mean    94813.859575       0.958294       0.767258       0.837414
# std     47488.145955       0.033276       0.017424       0.026275
# min         0.000000       0.000000       0.000000       0.000000
# 25%     54201.500000       0.942658       0.760943       0.821985
# 50%     84692.000000       0.958601       0.767949       0.840530
# 75%    139320.500000       0.980645       0.775739       0.855213
# max    172792.000000       1.000000       1.000000       1.000000
#
#                   V4             V5             V6             V7  \
# count  284807.000000  284807.000000  284807.000000  284807.000000
# mean        0.251930       0.765716       0.263020       0.265356
# std         0.062764       0.009292       0.013395       0.007537
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# #### 3.3 컬럼삭제

# %%
data = data.drop('Time', axis = 1)

# %%
data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'],
#       dtype='object')

# %% [markdown]
# ### 4. 데이터 분리 및 저장

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('Class',axis = 1)
y = data[['Class']]
X_train, X_test, y_train, y_test = train_test_split(X, y,
                    random_state = 7, test_size = 0.3, stratify = y)

# %%
fig, ax = plt.subplots(figsize = (12, 6))
y_train['Class'].value_counts().plot(kind = 'bar', color = color_pal[18:], 
                        edgecolor='#404040', ax = ax, fontsize = 12, rot = 0)

for p in ax.patches:
    ax.text(p.get_x()+p.get_width()/2., p.get_height()+1000, 
            str(p.get_height())+'('+str(round((p.get_height()/y_train.shape[0])*100,
            2))+ '%)', ha='center', fontsize = 20)

ax.set_title('Train Data')
ax.set_xticklabels(['normal(0)', 'fraud(1)'], fontsize = 20)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12, 6))
y_test['Class'].value_counts().plot(kind = 'bar', color = color_pal[18:], 
                        edgecolor='#404040', ax = ax, fontsize = 12, rot = 0)

for p in ax.patches:
    ax.text(p.get_x()+p.get_width()/2., p.get_height()+1000, 
            str(p.get_height())+'('+str(round((p.get_height()/y_test.shape[0])*100,
            2))+ '%)', ha='center', fontsize = 20)

ax.set_title('Test Data')
ax.set_xticklabels(['normal(0)', 'fraud(1)'], fontsize = 20)
plt.show()

# %%
X_train.to_csv('X_train.csv', index = False)
X_test.to_csv('X_test.csv', index = False)
y_train.to_csv('y_train.csv', index = False)
y_test.to_csv('y_test.csv', index = False)
